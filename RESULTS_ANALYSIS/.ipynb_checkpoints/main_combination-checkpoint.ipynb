# %% [markdown]
# ## Import Libraries

# %%
import os
import itertools
from tqdm import tqdm

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Experiment Names and Combinations

# %%
configurations = {
    "crossover": {
        "Single Point Crossover": None,
        "Two Point Crossover": None,
        "Uniform Crossover": None,
        "Blend Crossover": None,
        "Arithmetic Crossover": None
    },
    "mutation_rate":{
        "1 Percent": None,
        "5 Percent": None,
        "10 Percent": None,
    },
    "mutation": {
        # "Random Resetting Mutation": lambda individual, mutation_rate: random_resetting_mutation(individual=individual, mutation_rate=mutation_rate),
        "Creep Mutation": None,
        "Gaussian Mutation": None,
        # "Boundary Mutation": lambda individual, mutation_rate: boundary_mutation(individual=individual, mutation_rate=mutation_rate),
        "Uniform Mutation": None
    },
    "selection": {
        "Roulette Wheel Selection": None,
        "Binary Tournament Selection": None,
        "Ternary Tournament Selection": None,
        "Rank Selection": None,
        "Stochastic Universal Selection": None,
        "Elitism Selection": None
    },
    "survivor_selection": {
        "Truncation Survivor Selection": None,
        "Steady State Selection": None
    }
}

# %%
def generate_experiment_combinations(configurations):
    # Extract the keys and values for each configuration category
    categories = {k: list(configurations[k].items()) for k in configurations}

    # Generate all possible combinations using itertools.product
    all_combinations = itertools.product(*categories.values())

    experiment_names = []
    experiment_functions = []

    for combination in all_combinations:
        # Create the experiment name by concatenating the keys with ' + '
        experiment_name = ' + '.join([c[0] for c in combination])
        experiment_names.append(experiment_name)

        # Collect the corresponding functions and their parameters
        experiment_funcs = [c[1] for c in combination]
        experiment_functions.append(experiment_funcs)

    return experiment_names, experiment_functions

experiment_names, experiment_functions = generate_experiment_combinations(configurations)
short_experiment_names = [ f"Combination_Experiment_{name}" for name in range(1, len(experiment_names)+1)]

# %%
experiment_name_dict = dict(zip(short_experiment_names, experiment_names))

# %%
def process_experiment_name(experiment_name):
    # Split the string using '+' and strip whitespace
    parts = [part.strip() for part in experiment_name.split('+')]

    # Initialize the dictionary
    experiment_dict = {
        "Crossover": None,
        "Mutation Rate": None,
        "Mutation": None,
        "Selection": None,
        "Survivor Selection": None
    }

    # Assign each part to its respective category
    for part in parts:
        if "Crossover" in part:
            experiment_dict["Crossover"] = part
        elif "Percent" in part:
            # Remove 'Percent', convert to float, and divide by 100
            mutation_rate = float(part.replace('Percent', '').strip()) / 100
            experiment_dict["Mutation Rate"] = mutation_rate
        elif "Mutation" in part and "Percent" not in part:
            experiment_dict["Mutation"] = part
        elif ("Selection" in part and "Survivor" not in part) and ("State" not in part):
            experiment_dict["Selection"] = part
        elif ("Survivor" in part) or ("State" in part):
            experiment_dict["Survivor Selection"] = part

    return experiment_dict

# %%
len(experiment_names)
# Out:
# 540

# %%
experiment_names[1]
# Out:
# 'Single Point Crossover + 1 Percent + Creep Mutation + Roulette Wheel Selection + Steady State Selection'

# %%
process_experiment_name(experiment_names[1])
# Out:
# {'Crossover': 'Single Point Crossover',
#  'Mutation Rate': 0.01,
#  'Mutation': 'Creep Mutation',
#  'Selection': 'Roulette Wheel Selection',
#  'Survivor Selection': 'Steady State Selection'}

# %% [markdown]
# ## Create Base Data

# %%
df = pd.DataFrame({"Experiment Name":short_experiment_names, "Configuration":experiment_names})

# %%
df_processed = df['Configuration'].apply(process_experiment_name)
df_processed = pd.json_normalize(df_processed)

# %%
base_df = pd.concat([df, df_processed], axis=1)
base_df = base_df.drop(["Configuration"], axis=1)

# %%
base_df
# Out:
#                 Experiment Name               Crossover  Mutation Rate  \
# 0      Combination_Experiment_1  Single Point Crossover           0.01
# 1      Combination_Experiment_2  Single Point Crossover           0.01
# 2      Combination_Experiment_3  Single Point Crossover           0.01
# 3      Combination_Experiment_4  Single Point Crossover           0.01
# 4      Combination_Experiment_5  Single Point Crossover           0.01
# ..                          ...                     ...            ...
# 535  Combination_Experiment_536    Arithmetic Crossover           0.10
# 536  Combination_Experiment_537    Arithmetic Crossover           0.10
# 537  Combination_Experiment_538    Arithmetic Crossover           0.10
# 538  Combination_Experiment_539    Arithmetic Crossover           0.10
# 539  Combination_Experiment_540    Arithmetic Crossover           0.10
#
#              Mutation                       Selection  \
# 0      Creep Mutation        Roulette Wheel Selection
# 1      Creep Mutation        Roulette Wheel Selection
# 2      Creep Mutation     Binary Tournament Selection
# 3      Creep Mutation     Binary Tournament Selection
# 4      Creep Mutation    Ternary Tournament Selection
# ..                ...                             ...
# 535  Uniform Mutation                  Rank Selection
# 536  Uniform Mutation  Stochastic Universal Selection
# 537  Uniform Mutation  Stochastic Universal Selection
# 538  Uniform Mutation               Elitism Selection
# 539  Uniform Mutation               Elitism Selection
#
#                 Survivor Selection
# 0    Truncation Survivor Selection
# 1           Steady State Selection
# 2    Truncation Survivor Selection
# 3           Steady State Selection
# 4    Truncation Survivor Selection
# ..                             ...
# 535         Steady State Selection
# 536  Truncation Survivor Selection
# 537         Steady State Selection
# 538  Truncation Survivor Selection
# 539         Steady State Selection
#
# [540 rows x 6 columns]

# %% [markdown]
# ## Generation Based Statistics

# %%
Experiments = df["Experiment Name"].to_list()

# %%
def get_file_from_list(file_list, generation):
    target = f"Results_Gen_{generation}_"
    x = [x for x in file_list if target in x]
    if len(x) == 0:
        return np.nan
    return x[0]

# %%
get_file_from_list(os.listdir("../RESULTS/Combination_Experiment_1/"), 100)
# Out:
# 'Results_Gen_100_20231225_171944.txt'

# %%
def get_file_dicts_for_folder(experiment):
    try:
        file_list = os.listdir(f"../RESULTS/{experiment}/")
    except:
        file_list = []
        
    result_dict = {}
    for i in range(1, 101):
        result_dict[i] = get_file_from_list(file_list, i)
        
    return result_dict

# %%
gen_result_files = get_file_dicts_for_folder(Experiments[1])

# %%
# gen_result_files

# %%
# Initialize an empty list to store new rows
new_rows = []

# Iterate over each row in df_combined
for index, row in tqdm(base_df.iterrows()):
    # For each generation number and file in the generation_data dictionary
    experiment_name = row["Experiment Name"]
    generation_data = get_file_dicts_for_folder(experiment_name)
    
    for gen_number, gen_file in generation_data.items():
        # Create a new row with the combined data and generation info
        new_row = row.to_dict()
        new_row['Generation Number'] = gen_number
        if gen_file is np.nan:
             new_row['Generation Log File'] = np.nan
        else:
            new_row['Generation Log File'] = f"../RESULTS/{experiment_name}/{gen_file}"
        new_rows.append(new_row)

# Create a new DataFrame from the new rows
df_generation = pd.DataFrame(new_rows)
# Out:
# 540it [00:01, 519.82it/s]

# %%
df_generation = df_generation.dropna()

# %%
df_generation
# Out:
#                   Experiment Name               Crossover  Mutation Rate  \
# 0        Combination_Experiment_1  Single Point Crossover           0.01
# 1        Combination_Experiment_1  Single Point Crossover           0.01
# 2        Combination_Experiment_1  Single Point Crossover           0.01
# 3        Combination_Experiment_1  Single Point Crossover           0.01
# 4        Combination_Experiment_1  Single Point Crossover           0.01
# ...                           ...                     ...            ...
# 52995  Combination_Experiment_530    Arithmetic Crossover           0.10
# 52996  Combination_Experiment_530    Arithmetic Crossover           0.10
# 52997  Combination_Experiment_530    Arithmetic Crossover           0.10
# 52998  Combination_Experiment_530    Arithmetic Crossover           0.10
# 52999  Combination_Experiment_530    Arithmetic Crossover           0.10
#
#                Mutation                 Selection  \
# 0        Creep Mutation  Roulette Wheel Selection
# 1        Creep Mutation  Roulette Wheel Selection
# 2        Creep Mutation  Roulette Wheel Selection
# 3        Creep Mutation  Roulette Wheel Selection
# 4        Creep Mutation  Roulette Wheel Selection
# ...                 ...                       ...
# 52995  Uniform Mutation  Roulette Wheel Selection
# 52996  Uniform Mutation  Roulette Wheel Selection
# 52997  Uniform Mutation  Roulette Wheel Selection
# 52998  Uniform Mutation  Roulette Wheel Selection
# 52999  Uniform Mutation  Roulette Wheel Selection
#
#                   Survivor Selection  Generation Number  \
# 0      Truncation Survivor Selection                  1
# 1      Truncation Survivor Selection                  2
# 2      Truncation Survivor Selection                  3
# 3      Truncation Survivor Selection                  4
# 4      Truncation Survivor Selection                  5
# ...                              ...                ...
# 52995         Steady State Selection                 96
# 52996         Steady State Selection                 97
# 52997         Steady State Selection                 98
# 52998         Steady State Selection                 99
# 52999         Steady State Selection                100
#
#                                      Generation Log File
# 0      ../RESULTS/Combination_Experiment_1/Results_Ge...
# 1      ../RESULTS/Combination_Experiment_1/Results_Ge...
# 2      ../RESULTS/Combination_Experiment_1/Results_Ge...
# 3      ../RESULTS/Combination_Experiment_1/Results_Ge...
# 4      ../RESULTS/Combination_Experiment_1/Results_Ge...
# ...                                                  ...
# 52995  ../RESULTS/Combination_Experiment_530/Results_...
# 52996  ../RESULTS/Combination_Experiment_530/Results_...
# 52997  ../RESULTS/Combination_Experiment_530/Results_...
# 52998  ../RESULTS/Combination_Experiment_530/Results_...
# 52999  ../RESULTS/Combination_Experiment_530/Results_...
#
# [12799 rows x 8 columns]

# %%
def read_experiment_results(file_path: str):
    """
    Reads the experiment results from a text file and extracts genotypes, fitness values, and detailed results.

    Parameters:
    - file_path (str): The path to the results file.

    Returns:
    - Tuple of three elements:
      1. List of genotypes
      2. Dictionary of genotype fitness values
      3. Dictionary of detailed results for each genotype
    """
    genotypes = []
    fitness_values = {}
    detailed_results = {}

    with open(file_path, 'r') as file:
        lines = file.readlines()

        reading_genotypes = False
        reading_detailed_results = False
        current_genotype = None

        for line in lines:
            line = line.strip()

            # Check for sections in the file
            if "Genotypes and their Fitness Values:" in line:
                reading_genotypes = True
                reading_detailed_results = False
                continue
            elif "Detailed Results for Each Genotype:" in line:
                reading_genotypes = False
                reading_detailed_results = True
                continue

            # Process the appropriate section
            if reading_genotypes and '-' in line:
                genotype_str, fitness_str = line.split('- Fitness:')
                genotype = eval(genotype_str.strip())
                fitness = float(fitness_str.strip())
                genotypes.append(genotype)
                fitness_values[tuple(genotype)] = fitness
            elif reading_detailed_results and 'Genotype' in line:
                genotype_str = line.split('Genotype ')[1].split(':')[0].strip()
                current_genotype = eval(genotype_str)
                detailed_results[tuple(current_genotype)] = {}
            elif reading_detailed_results and 'Angle' in line:
                parts = line.split(':')
                angle = int(parts[0].split()[1])
                values_str = parts[1].split(',')
                cl = float(values_str[0].split('=')[1])
                cd = float(values_str[1].split('=')[1])
                cm = float(values_str[2].split('=')[1])
                detailed_results[tuple(current_genotype)][angle] = (cl, cd, cm)

    return genotypes, fitness_values, detailed_results

# %%
genotypes, fitness_values, detailed_results = read_experiment_results(df_generation["Generation Log File"].iloc[0])

# %%
str(genotypes[0])
# Out:
# '[0.009850677664866372, 0.4409133916170535, 0.1295487342146977, -0.7808051360146988, 0.253436479224651, -0.022716056755466764, 0.10974741654937767, -0.0039984601259599635, 0.004301339473160307, 8.794923268059222, 10.88010326978484]'

# %%
fitness_values[tuple(genotypes[0])]
# Out:
# -0.709099026747874

# %%
detailed_results[tuple(genotypes[0])]
# detailed_results.values()
# Out:
# {-10: (-0.5367875099182129, 0.19459985196590424, -0.17556194961071014),
#  -9: (-0.5796747207641602, 0.16981622576713562, -0.1671973615884781),
#  -8: (-0.6098834872245789, 0.14074069261550903, -0.16190241277217865),
#  -7: (-0.6330243349075317, 0.11831288784742355, -0.15306957066059113),
#  -6: (-0.6265453100204468, 0.10450922697782516, -0.13153846561908722),
#  -5: (-0.545254647731781, 0.0943913459777832, -0.10635118186473846),
#  -4: (-0.4622024595737457, 0.08663022518157959, -0.08236844837665558),
#  -3: (-0.38016271591186523, 0.08171126246452332, -0.058460935950279236),
#  -2: (-0.3191322982311249, 0.0875745415687561, -0.04131166636943817),
#  -1: (-0.27213650941848755, 0.09481785446405411, -0.023743048310279846),
#  0: (-0.21395453810691833, 0.10151425004005432, -0.006923899054527283),
#  1: (-0.14427490532398224, 0.10770045965909958, 0.007953748106956482),
#  2: (0.0223616361618042, 0.10413671284914017, 0.015959948301315308),
#  3: (0.11378009617328644, 0.1057182103395462, 0.015352055430412292),
#  4: (0.19498705863952637, 0.10732991248369217, 0.011274740099906921),
#  5: (0.28112921118736267, 0.10914399474859238, 0.00645098090171814),
#  6: (0.3749546408653259, 0.11072392761707306, 0.001765131950378418),
#  7: (0.49635303020477295, 0.10853508859872818, -0.014937475323677063),
#  8: (0.6120504140853882, 0.1067752093076706, -0.035815104842185974),
#  9: (0.7253792881965637, 0.10525503009557724, -0.05998341739177704),
#  10: (0.8404616713523865, 0.10328438878059387, -0.08445753157138824)}

# %%
# genotypes[0]

# %%
# list(fitness_values.values())

# %%
def get_fitness_stats(experiment_file):
    genotypes, fitness_values, detailed_result = read_experiment_results(experiment_file)
    
    fitness_values = list(fitness_values.values())

    # Compute the statistics as shown above
    best_fitness = np.max(fitness_values)
    lowest_fitness = np.min(fitness_values)
    average_fitness = np.mean(fitness_values)
    std_dev_fitness = np.std(fitness_values)
    median_fitness = np.median(fitness_values)
    
    return best_fitness, lowest_fitness, average_fitness, std_dev_fitness, median_fitness

# %%
# %%time
get_fitness_stats(df_generation["Generation Log File"].iloc[0])
# Out:
# CPU times: total: 0 ns
# Wall time: 10.5 ms
# (-0.709099026747874,
#  -2.1715093604877564,
#  -1.7571522461664144,
#  0.33894842771971617,
#  -1.8810802473780226)

# %%
# Define a function that takes a row and returns a Series with the fitness statistics
def fitness_stats_row(row):
    file_path = row['Generation Log File']
    best_fitness, lowest_fitness, average_fitness, std_dev_fitness, median_fitness = get_fitness_stats(file_path)
    return pd.Series([best_fitness, lowest_fitness, average_fitness, std_dev_fitness, median_fitness])

# %%
fitness_stats_list = []

# Iterate over each row in the DataFrame with tqdm
for _, row in tqdm(df_generation.iterrows(), total=df_generation.shape[0], desc="Processing rows"):
    fitness_stats = fitness_stats_row(row)
    # Append the results to the list
    fitness_stats_list.append(fitness_stats)
# Out:
# Processing rows: 100%|███████████████████████████████████████████████████| 12799/12799 [02:08<00:00, 99.68it/s]

# %%
# Create the DataFrame from the collected statistics
fitness_stats_df = pd.DataFrame(fitness_stats_list,)
fitness_stats_df.columns = ['Best Fitness', 'Lowest Fitness', 'Average Fitness', 'Standard Deviation Fitness', 'Median Fitness']

# Combine the original DataFrame with the new fitness stats DataFrame
df_combined = pd.concat([df_generation.reset_index(drop=True), fitness_stats_df], axis=1)

# %%
# Display the combined DataFrame
df_combined
# Out:
#                   Experiment Name               Crossover  Mutation Rate  \
# 0        Combination_Experiment_1  Single Point Crossover           0.01
# 1        Combination_Experiment_1  Single Point Crossover           0.01
# 2        Combination_Experiment_1  Single Point Crossover           0.01
# 3        Combination_Experiment_1  Single Point Crossover           0.01
# 4        Combination_Experiment_1  Single Point Crossover           0.01
# ...                           ...                     ...            ...
# 12794  Combination_Experiment_530    Arithmetic Crossover           0.10
# 12795  Combination_Experiment_530    Arithmetic Crossover           0.10
# 12796  Combination_Experiment_530    Arithmetic Crossover           0.10
# 12797  Combination_Experiment_530    Arithmetic Crossover           0.10
# 12798  Combination_Experiment_530    Arithmetic Crossover           0.10
#
#                Mutation                 Selection  \
# 0        Creep Mutation  Roulette Wheel Selection
# 1        Creep Mutation  Roulette Wheel Selection
# 2        Creep Mutation  Roulette Wheel Selection
# 3        Creep Mutation  Roulette Wheel Selection
# 4        Creep Mutation  Roulette Wheel Selection
# ...                 ...                       ...
# 12794  Uniform Mutation  Roulette Wheel Selection
# 12795  Uniform Mutation  Roulette Wheel Selection
# 12796  Uniform Mutation  Roulette Wheel Selection
# 12797  Uniform Mutation  Roulette Wheel Selection
# 12798  Uniform Mutation  Roulette Wheel Selection
#
#                   Survivor Selection  Generation Number  \
# 0      Truncation Survivor Selection                  1
# 1      Truncation Survivor Selection                  2
# 2      Truncation Survivor Selection                  3
# 3      Truncation Survivor Selection                  4
# 4      Truncation Survivor Selection                  5
# ...                              ...                ...
# 12794         Steady State Selection                 96
# 12795         Steady State Selection                 97
# 12796         Steady State Selection                 98
# 12797         Steady State Selection                 99
# 12798         Steady State Selection                100
#
#                                      Generation Log File  Best Fitness  \
# 0      ../RESULTS/Combination_Experiment_1/Results_Ge...     -0.709099
# 1      ../RESULTS/Combination_Experiment_1/Results_Ge...     -0.664416
# 2      ../RESULTS/Combination_Experiment_1/Results_Ge...     -0.664416
# 3      ../RESULTS/Combination_Experiment_1/Results_Ge...     -0.538296
# 4      ../RESULTS/Combination_Experiment_1/Results_Ge...     -0.442628
# ...                                                  ...           ...
# 12794  ../RESULTS/Combination_Experiment_530/Results_...     -0.203841
# 12795  ../RESULTS/Combination_Experiment_530/Results_...     -0.187059
# 12796  ../RESULTS/Combination_Experiment_530/Results_...     -0.187059
# 12797  ../RESULTS/Combination_Experiment_530/Results_...     -0.187059
# 12798  ../RESULTS/Combination_Experiment_530/Results_...     -0.187059
#
#        Lowest Fitness  Average Fitness  Standard Deviation Fitness  \
# 0           -2.171509        -1.757152                    0.338948
# 1           -1.880508        -1.557737                    0.311080
# 2           -1.613202        -1.297397                    0.247769
# 3           -1.326752        -1.071519                    0.206682
# 4           -1.130396        -0.901424                    0.154906
# ...               ...              ...                         ...
# 12794       -0.396032        -0.291401                    0.033793
# 12795       -0.399710        -0.287231                    0.038985
# 12796       -0.411044        -0.280092                    0.038848
# 12797       -0.414061        -0.274998                    0.035363
# 12798       -0.399100        -0.266161                    0.034539
#
#        Median Fitness
# 0           -1.881080
# 1           -1.698041
# 2           -1.326137
# 3           -1.144199
# 4           -0.917703
# ...               ...
# 12794       -0.287802
# 12795       -0.280527
# 12796       -0.275750
# 12797       -0.272554
# 12798       -0.260202
#
# [12799 rows x 13 columns]

# %% [markdown]
# ## Best Generation based Fitness

# %%
df_combined.sort_values(by="Best Fitness", ascending=False).drop_duplicates(subset="Experiment Name", keep='first')
# Out:
#                  Experiment Name               Crossover  Mutation Rate  \
# 5099  Combination_Experiment_351         Blend Crossover           0.01
# 1496   Combination_Experiment_15  Single Point Crossover           0.01
# 1981   Combination_Experiment_20  Single Point Crossover           0.01
# 1267   Combination_Experiment_13  Single Point Crossover           0.01
# 1695   Combination_Experiment_17  Single Point Crossover           0.01
# ...                          ...                     ...            ...
# 2126   Combination_Experiment_22  Single Point Crossover           0.01
# 8184  Combination_Experiment_382         Blend Crossover           0.05
# 3355   Combination_Experiment_34  Single Point Crossover           0.01
# 984    Combination_Experiment_10  Single Point Crossover           0.01
# 5789  Combination_Experiment_358         Blend Crossover           0.01
#
#                Mutation                       Selection  \
# 5099   Uniform Mutation     Binary Tournament Selection
# 1496  Gaussian Mutation     Binary Tournament Selection
# 1981  Gaussian Mutation                  Rank Selection
# 1267  Gaussian Mutation        Roulette Wheel Selection
# 1695  Gaussian Mutation    Ternary Tournament Selection
# ...                 ...                             ...
# 2126  Gaussian Mutation  Stochastic Universal Selection
# 8184  Gaussian Mutation  Stochastic Universal Selection
# 3355   Uniform Mutation  Stochastic Universal Selection
# 984      Creep Mutation  Stochastic Universal Selection
# 5789   Uniform Mutation  Stochastic Universal Selection
#
#                  Survivor Selection  Generation Number  \
# 5099  Truncation Survivor Selection                100
# 1496  Truncation Survivor Selection                 97
# 1981         Steady State Selection                 82
# 1267  Truncation Survivor Selection                 68
# 1695  Truncation Survivor Selection                 96
# ...                             ...                ...
# 2126         Steady State Selection                 27
# 8184         Steady State Selection                 85
# 3355         Steady State Selection                 56
# 984          Steady State Selection                 85
# 5789         Steady State Selection                 90
#
#                                     Generation Log File  Best Fitness  \
# 5099  ../RESULTS/Combination_Experiment_351/Results_...      2.765205
# 1496  ../RESULTS/Combination_Experiment_15/Results_G...      0.291821
# 1981  ../RESULTS/Combination_Experiment_20/Results_G...      0.291821
# 1267  ../RESULTS/Combination_Experiment_13/Results_G...      0.291821
# 1695  ../RESULTS/Combination_Experiment_17/Results_G...      0.291821
# ...                                                 ...           ...
# 2126  ../RESULTS/Combination_Experiment_22/Results_G...     -0.981673
# 8184  ../RESULTS/Combination_Experiment_382/Results_...     -1.074310
# 3355  ../RESULTS/Combination_Experiment_34/Results_G...     -1.106211
# 984   ../RESULTS/Combination_Experiment_10/Results_G...     -1.117261
# 5789  ../RESULTS/Combination_Experiment_358/Results_...     -1.180817
#
#       Lowest Fitness  Average Fitness  Standard Deviation Fitness  \
# 5099        2.739503         2.747831                    0.005623
# 1496        0.291088         0.291454                    0.000367
# 1981        0.288753         0.290287                    0.001534
# 1267        0.288574         0.290158                    0.001164
# 1695        0.283992         0.287821                    0.003293
# ...              ...              ...                         ...
# 2126       -2.200380        -1.849215                    0.298707
# 8184       -2.249923        -1.616167                    0.311398
# 3355       -2.241018        -1.905953                    0.306086
# 984        -2.766485        -2.101724                    0.396935
# 5789       -2.219496        -1.789715                    0.346036
#
#       Median Fitness
# 5099        2.747006
# 1496        0.291454
# 1981        0.290287
# 1267        0.290120
# 1695        0.287884
# ...              ...
# 2126       -1.942573
# 8184       -1.569877
# 3355       -2.003497
# 984        -2.173882
# 5789       -1.804840
#
# [128 rows x 13 columns]

# %%
df_combined.to_csv("./assets/generation_fitness.csv", index=False)

# %% [markdown]
# ## Generation Based Angle of Attack Analysis

# %%
def get_aoa_measurement_stats_dict(experiment_file):
    genotypes, fitness_values, detailed_result = read_experiment_results(experiment_file)
    dicts_list = list(detailed_result.values())
    
    measurements = {
        angle: {'CL': [], 'CD': [], 'CM': []} for angle in range(-10, 11)
    }

    # Accumulate values from each dictionary in the list
    for d in dicts_list:
        for angle, (cl, cd, cm) in d.items():
            measurements[angle]['CL'].append(cl)
            measurements[angle]['CD'].append(cd)
            measurements[angle]['CM'].append(cm)

    # Prepare data for the final dictionary
    final_stats = {}
    for angle in range(-10, 11):
        for measure_type in ['CL', 'CD', 'CM']:
            values = measurements[angle][measure_type]
            final_stats[f'Angle {angle} {measure_type} Mean'] = np.mean(values)
            final_stats[f'Angle {angle} {measure_type} Max'] = np.max(values)
            final_stats[f'Angle {angle} {measure_type} Median'] = np.median(values)
            final_stats[f'Angle {angle} {measure_type} Std Dev'] = np.std(values)
            final_stats[f'Angle {angle} {measure_type} Min'] = np.min(values)

    return final_stats

# %%
# %%time
sample_dict = get_aoa_measurement_stats_dict(df_generation["Generation Log File"].iloc[0])
len(sample_dict)
# Out:
# CPU times: total: 0 ns
# Wall time: 18.8 ms
# 315

# %%
aoa_stats_list = []

# Iterate over each row in the DataFrame with tqdm
for _, row in tqdm(df_combined.iterrows(), total=df_combined.shape[0], desc="Processing rows"):
    aoa_stats = get_aoa_measurement_stats_dict(row["Generation Log File"])
    # Append the results to the list
    aoa_stats_list.append(aoa_stats)
# Out:
# Processing rows: 100%|███████████████████████████████████████████████████| 12799/12799 [03:36<00:00, 59.13it/s]

# %%
# Create the DataFrame from the collected statistics
aoa_stats_df = pd.DataFrame(aoa_stats_list)
aoa_stats_df.columns = list(sample_dict.keys())

# Combine the original DataFrame with the new fitness stats DataFrame
df_full_combined = pd.concat([df_generation.reset_index(drop=True), aoa_stats_df], axis=1)

# %%
df_full_combined
# Out:
#                   Experiment Name               Crossover  Mutation Rate  \
# 0        Combination_Experiment_1  Single Point Crossover           0.01
# 1        Combination_Experiment_1  Single Point Crossover           0.01
# 2        Combination_Experiment_1  Single Point Crossover           0.01
# 3        Combination_Experiment_1  Single Point Crossover           0.01
# 4        Combination_Experiment_1  Single Point Crossover           0.01
# ...                           ...                     ...            ...
# 12794  Combination_Experiment_530    Arithmetic Crossover           0.10
# 12795  Combination_Experiment_530    Arithmetic Crossover           0.10
# 12796  Combination_Experiment_530    Arithmetic Crossover           0.10
# 12797  Combination_Experiment_530    Arithmetic Crossover           0.10
# 12798  Combination_Experiment_530    Arithmetic Crossover           0.10
#
#                Mutation                 Selection  \
# 0        Creep Mutation  Roulette Wheel Selection
# 1        Creep Mutation  Roulette Wheel Selection
# 2        Creep Mutation  Roulette Wheel Selection
# 3        Creep Mutation  Roulette Wheel Selection
# 4        Creep Mutation  Roulette Wheel Selection
# ...                 ...                       ...
# 12794  Uniform Mutation  Roulette Wheel Selection
# 12795  Uniform Mutation  Roulette Wheel Selection
# 12796  Uniform Mutation  Roulette Wheel Selection
# 12797  Uniform Mutation  Roulette Wheel Selection
# 12798  Uniform Mutation  Roulette Wheel Selection
#
#                   Survivor Selection  Generation Number  \
# 0      Truncation Survivor Selection                  1
# 1      Truncation Survivor Selection                  2
# 2      Truncation Survivor Selection                  3
# 3      Truncation Survivor Selection                  4
# 4      Truncation Survivor Selection                  5
# ...                              ...                ...
# 12794         Steady State Selection                 96
# 12795         Steady State Selection                 97
# 12796         Steady State Selection                 98
# 12797         Steady State Selection                 99
# 12798         Steady State Selection                100
#
#                                      Generation Log File  Angle -10 CL Mean  \
# 0      ../RESULTS/Combination_Experiment_1/Results_Ge...          -0.597010
# 1      ../RESULTS/Combination_Experiment_1/Results_Ge...          -0.585426
# 2      ../RESULTS/Combination_Experiment_1/Results_Ge...          -0.578159
# 3      ../RESULTS/Combination_Experiment_1/Results_Ge...          -0.573267
# 4      ../RESULTS/Combination_Experiment_1/Results_Ge...          -0.569276
# ...                                                  ...                ...
# 12794  ../RESULTS/Combination_Experiment_530/Results_...          -0.555318
# 12795  ../RESULTS/Combination_Experiment_530/Results_...          -0.555374
# 12796  ../RESULTS/Combination_Experiment_530/Results_...          -0.555005
# 12797  ../RESULTS/Combination_Experiment_530/Results_...          -0.555770
# 12798  ../RESULTS/Combination_Experiment_530/Results_...          -0.555711
#
#        Angle -10 CL Max  ...  Angle 10 CD Mean  Angle 10 CD Max  \
# 0             -0.536788  ...          0.103422         0.120719
# 1             -0.536788  ...          0.102738         0.110802
# 2             -0.536788  ...          0.103667         0.111391
# 3             -0.536788  ...          0.105286         0.112437
# 4             -0.536788  ...          0.107159         0.112437
# ...                 ...  ...               ...              ...
# 12794         -0.548676  ...          0.112927         0.113465
# 12795         -0.548676  ...          0.112892         0.113403
# 12796         -0.548676  ...          0.112905         0.113412
# 12797         -0.548676  ...          0.112835         0.113273
# 12798         -0.548676  ...          0.112838         0.113316
#
#        Angle 10 CD Median  Angle 10 CD Std Dev  Angle 10 CD Min  \
# 0                0.102373             0.004197         0.098830
# 1                0.102023             0.002346         0.098967
# 2                0.103328             0.002726         0.099613
# 3                0.104104             0.003204         0.100804
# 4                0.107553             0.003574         0.101101
# ...                   ...                  ...              ...
# 12794            0.113027             0.000369         0.111801
# 12795            0.112960             0.000306         0.112021
# 12796            0.112924             0.000302         0.111977
# 12797            0.112860             0.000303         0.111926
# 12798            0.112829             0.000294         0.111926
#
#        Angle 10 CM Mean  Angle 10 CM Max  Angle 10 CM Median  \
# 0             -0.143825        -0.015588           -0.143599
# 1             -0.120349        -0.015588           -0.121428
# 2             -0.092790        -0.006024           -0.104323
# 3             -0.072608        -0.005813           -0.075632
# 4             -0.050819        -0.005813           -0.053485
# ...                 ...              ...                 ...
# 12794         -0.013612        -0.009788           -0.013251
# 12795         -0.013722        -0.009788           -0.013024
# 12796         -0.013332        -0.009788           -0.012620
# 12797         -0.012740        -0.009565           -0.012301
# 12798         -0.012731        -0.009565           -0.012264
#
#        Angle 10 CM Std Dev  Angle 10 CM Min
# 0                 0.053236        -0.280391
# 1                 0.041906        -0.222822
# 2                 0.036951        -0.166879
# 3                 0.038511        -0.146172
# 4                 0.033230        -0.110576
# ...                    ...              ...
# 12794             0.002156        -0.021402
# 12795             0.002323        -0.021077
# 12796             0.002001        -0.019936
# 12797             0.001781        -0.019543
# 12798             0.001693        -0.018359
#
# [12799 rows x 323 columns]

# %%
df_full_combined.to_csv("./assets/generation_fitness_and_aoa.csv", index=False)

# %% [markdown]
# ## Experiment Based Statistics

# %%
def get_experiment_assets(experiment_name):
    log_files = list(get_file_dicts_for_folder(experiment_name).values())
    log_file_paths = [f"../RESULTS/{experiment_name}/{x}" for x in log_files]
    
    genotypes, fitness_values, detailed_results = [], {}, {}
    
    for file in log_file_paths:
        g, f, d = read_experiment_results(file)
        genotypes.extend(g)
        fitness_values = {**fitness_values, **f}
        detailed_results = {**detailed_results, **d}
    
    return genotypes, fitness_values, detailed_results

# %%
# %%time
genotypes, fitness_values, detailed_results = get_experiment_assets(Experiments[0])
# Out:
# CPU times: total: 594 ms
# Wall time: 966 ms

# %%
def get_experiment_fitness_stats(experiment_name):
    genotypes, fitness_values, detailed_result = get_experiment_assets(experiment_name)
    
    fitness_values = list(fitness_values.values())

    # Compute the statistics as shown above
    best_fitness = np.max(fitness_values)
    lowest_fitness = np.min(fitness_values)
    average_fitness = np.mean(fitness_values)
    std_dev_fitness = np.std(fitness_values)
    median_fitness = np.median(fitness_values)
    
    return best_fitness, lowest_fitness, average_fitness, std_dev_fitness, median_fitness

# %%
# %%time
get_experiment_fitness_stats(Experiments[0])
# Out:
# CPU times: total: 531 ms
# Wall time: 960 ms
# (0.1795747752690384,
#  -2.1715093604877564,
#  -0.48480516247256356,
#  0.6337861847438229,
#  -0.22995283583886844)

# %%
# Define a function that takes a row and returns a Series with the fitness statistics
def fitness_experiment_stats_row(row):
    file_path = row['Experiment Name']
    best_fitness, lowest_fitness, average_fitness, std_dev_fitness, median_fitness = get_experiment_fitness_stats(file_path)
    return pd.Series([best_fitness, lowest_fitness, average_fitness, std_dev_fitness, median_fitness])

# %%
# fitness_ex_stats_list = []

# # Iterate over each row in the DataFrame with tqdm
# for _, row in tqdm(df_generation.iterrows(), total=df_generation.shape[0], desc="Processing rows"):
#     fitness_stats = fitness_experiment_stats_row(row)
#     # Append the results to the list
#     fitness_ex_stats_list.append(fitness_stats)

# %%
# # Create the DataFrame from the collected statistics
# fitness_ex_stats_df = pd.DataFrame(fitness_stats_list,)
# fitness_ex_stats_df.columns = ['Best Fitness', 'Lowest Fitness', 'Average Fitness', 'Standard Deviation Fitness', 'Median Fitness']

# # Combine the original DataFrame with the new fitness stats DataFrame
# df_ex_combined = pd.concat([df_generation.reset_index(drop=True), fitness_ex_stats_df], axis=1)

# %%
# # Display the combined DataFrame
# df_ex_combined

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12799 entries, 0 to 12798
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Experiment Name             12799 non-null  object
#  1   Crossover                   12799 non-null  object
#  2   Mutation Rate               12799 non-null  float64
#  3   Mutation                    12799 non-null  object
#  4   Selection                   12799 non-null  object
#  5   Survivor Selection          12799 non-null  object
#  6   Generation Number           12799 non-null  int64
#  7   Generation Log File         12799 non-null  object
#  8   Best Fitness                12799 non-null  float64
#  9   Lowest Fitness              12799 non-null  float64
#  10  Average Fitness             12799 non-null  float64
#  11  Standard Deviation Fitness  12799 non-null  float64
#  12  Median Fitness              12799 non-null  float64
# dtypes: float64(6), int64(1), object(6)
# memory usage: 1.3+ MB

# %%
# Group the DataFrame by 'Experiment Name'
grouped = df_combined.groupby('Experiment Name')

# Calculate aggregate statistics for each group
experiment_stats = grouped.agg({
    'Best Fitness': 'max',
    'Lowest Fitness': 'min',
    'Average Fitness': 'mean',
    'Standard Deviation Fitness': 'mean',
    'Median Fitness': 'median'
}).reset_index()

# Optionally, sort the DataFrame based on a specific column (e.g., 'Best Fitness')
experiment_stats_sorted = experiment_stats.sort_values(by='Best Fitness', ascending=False)

experiment_stats_sorted
# Out:
#                Experiment Name  Best Fitness  Lowest Fitness  Average Fitness  \
# 29  Combination_Experiment_351      2.765205       -2.091331         1.929061
# 12   Combination_Experiment_20      0.291821       -2.584654         0.059409
# 4    Combination_Experiment_13      0.291821       -2.316307         0.043316
# 6    Combination_Experiment_15      0.291821       -2.067294         0.154890
# 8    Combination_Experiment_17      0.291821       -2.097023         0.155020
# ..                         ...           ...             ...              ...
# 14   Combination_Experiment_22     -0.981673       -2.702733        -1.788509
# 63  Combination_Experiment_382     -1.074310       -2.882388        -1.695960
# 27   Combination_Experiment_34     -1.106211       -2.785577        -1.937135
# 1    Combination_Experiment_10     -1.117261       -2.766485        -2.095250
# 36  Combination_Experiment_358     -1.180817       -2.708545        -1.836567
#
#     Standard Deviation Fitness  Median Fitness
# 29                    0.035425        2.243207
# 12                    0.075703        0.278912
# 4                     0.032609        0.262099
# 6                     0.021886        0.283387
# 8                     0.022199        0.275282
# ..                         ...             ...
# 14                    0.288548       -1.789595
# 63                    0.354616       -1.569877
# 27                    0.316065       -2.003497
# 1                     0.392865       -2.167869
# 36                    0.358240       -1.860528
#
# [128 rows x 6 columns]

# %%
len(list(df_full_combined.columns))
# Out:
# 323

# %%
columns = df_full_combined.columns

# Define a dictionary to map column suffixes to aggregation functions
agg_funcs_mapping = {
    'Mean': 'mean',
    'Max': 'max',
    'Median': 'median',
    'Std Dev': 'std',
    'Min': 'min'
}

# Create a dictionary for aggregation functions for each column
agg_funcs = {}
for col in columns:
    for suffix, func in agg_funcs_mapping.items():
        if suffix in col:
            agg_funcs[col] = func
            break  # Break the loop once a match is found

# Group the DataFrame by 'Experiment Name' and apply the aggregation
grouped = df_full_combined.groupby('Experiment Name')
detailed_experiment_stats = grouped.agg(agg_funcs).reset_index()

detailed_experiment_stats
# Out:
#                 Experiment Name  Angle -10 CL Mean  Angle -10 CL Max  \
# 0      Combination_Experiment_1          -0.561058         -0.531322
# 1     Combination_Experiment_10          -0.625255         -0.548692
# 2     Combination_Experiment_11          -0.563871         -0.527037
# 3     Combination_Experiment_12          -0.562653         -0.529226
# 4     Combination_Experiment_13          -0.563755         -0.537135
# ..                          ...                ...               ...
# 123  Combination_Experiment_530          -0.559309         -0.547521
# 124    Combination_Experiment_6          -0.556496         -0.519523
# 125    Combination_Experiment_7          -0.559948         -0.533494
# 126    Combination_Experiment_8          -0.564405         -0.534613
# 127    Combination_Experiment_9          -0.577421         -0.547740
#
#      Angle -10 CL Median  Angle -10 CL Std Dev  Angle -10 CL Min  \
# 0              -0.559860              0.004677         -0.650933
# 1              -0.623589              0.001774         -0.741821
# 2              -0.562930              0.004584         -0.640335
# 3              -0.561726              0.008283         -0.727808
# 4              -0.566968              0.005070         -0.679256
# ..                   ...                   ...               ...
# 123            -0.556272              0.004299         -0.673006
# 124            -0.558920              0.004761         -0.648815
# 125            -0.561668              0.003443         -0.647883
# 126            -0.563825              0.005736         -0.700853
# 127            -0.557618              0.014015         -0.712634
#
#      Angle -10 CD Mean  Angle -10 CD Max  Angle -10 CD Median  \
# 0             0.224533          0.233214             0.226045
# 1             0.194526          0.275764             0.191066
# 2             0.229469          0.235349             0.234953
# 3             0.223151          0.283793             0.234131
# 4             0.226965          0.235510             0.234486
# ..                 ...               ...                  ...
# 123           0.203450          0.221311             0.202841
# 124           0.222747          0.226739             0.226532
# 125           0.221983          0.231565             0.219367
# 126           0.227994          0.239629             0.233031
# 127           0.190280          0.243536             0.187979
#
#      Angle -10 CD Std Dev  ...  Angle 10 CD Mean  Angle 10 CD Max  \
# 0                0.002072  ...          0.110607         0.120719
# 1                0.001704  ...          0.108491         0.134029
# 2                0.002334  ...          0.110053         0.121434
# 3                0.003437  ...          0.109347         0.137025
# 4                0.001898  ...          0.110561         0.126739
# ..                    ...  ...               ...              ...
# 123              0.000707  ...          0.107919         0.119769
# 124              0.001865  ...          0.113545         0.116826
# 125              0.001899  ...          0.111877         0.113770
# 126              0.003029  ...          0.109587         0.125206
# 127              0.004163  ...          0.104206         0.130152
#
#      Angle 10 CD Median  Angle 10 CD Std Dev  Angle 10 CD Min  \
# 0              0.111124             0.000862         0.098830
# 1              0.104773             0.000372         0.099698
# 2              0.110995             0.000817         0.098388
# 3              0.109974             0.001158         0.098534
# 4              0.110929             0.000982         0.098318
# ..                  ...                  ...              ...
# 123            0.108445             0.000443         0.099304
# 124            0.114777             0.000920         0.100543
# 125            0.112125             0.000513         0.099726
# 126            0.109780             0.001011         0.099287
# 127            0.103273             0.002721         0.098589
#
#      Angle 10 CM Mean  Angle 10 CM Max  Angle 10 CM Median  \
# 0           -0.013231        -0.004263           -0.008122
# 1           -0.204331        -0.086689           -0.201193
# 2           -0.014542        -0.003809           -0.004193
# 3           -0.022904         0.005469           -0.004543
# 4           -0.015739        -0.003658           -0.004274
# ..                ...              ...                 ...
# 123         -0.052012        -0.009565           -0.040077
# 124         -0.014760         0.001247           -0.007693
# 125         -0.016488        -0.005519           -0.012043
# 126         -0.014671         0.004491           -0.005048
# 127         -0.136825        -0.074994           -0.114427
#
#      Angle 10 CM Std Dev  Angle 10 CM Min
# 0               0.010047        -0.280391
# 1               0.002256        -0.391234
# 2               0.010066        -0.298555
# 3               0.015267        -0.414701
# 4               0.010223        -0.339931
# ..                   ...              ...
# 123             0.007743        -0.302695
# 124             0.007867        -0.275074
# 125             0.006459        -0.241967
# 126             0.011392        -0.322895
# 127             0.024054        -0.365893
#
# [128 rows x 316 columns]

# %% [markdown]
# ## Data Visualization

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12799 entries, 0 to 12798
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Experiment Name             12799 non-null  object
#  1   Crossover                   12799 non-null  object
#  2   Mutation Rate               12799 non-null  float64
#  3   Mutation                    12799 non-null  object
#  4   Selection                   12799 non-null  object
#  5   Survivor Selection          12799 non-null  object
#  6   Generation Number           12799 non-null  int64
#  7   Generation Log File         12799 non-null  object
#  8   Best Fitness                12799 non-null  float64
#  9   Lowest Fitness              12799 non-null  float64
#  10  Average Fitness             12799 non-null  float64
#  11  Standard Deviation Fitness  12799 non-null  float64
#  12  Median Fitness              12799 non-null  float64
# dtypes: float64(6), int64(1), object(6)
# memory usage: 1.3+ MB

# %%
def get_max_fitness_by_generation(df, experiment_names):
    # Filter the DataFrame for the given experiment names
    filtered_df = df[df['Experiment Name'].isin(experiment_names)]

    # Group by 'Experiment Name' and 'Generation Number', then get the max 'Best Fitness'
    grouped = filtered_df.groupby(['Experiment Name', 'Generation Number'])['Best Fitness'].max()

    # Reset the index to turn it back to a DataFrame
    result_df = grouped.reset_index()

    # Sort the DataFrame by 'Experiment Name' and 'Generation Number'
    sorted_result_df = result_df.sort_values(by=['Experiment Name', 'Generation Number'])

    return sorted_result_df

# %%
fitnerss_based_df = get_max_fitness_by_generation(df_combined, [Experiments[0]])

# %%
fitnerss_based_df
# Out:
#              Experiment Name  Generation Number  Best Fitness
# 0   Combination_Experiment_1                  1     -0.709099
# 1   Combination_Experiment_1                  2     -0.664416
# 2   Combination_Experiment_1                  3     -0.664416
# 3   Combination_Experiment_1                  4     -0.538296
# 4   Combination_Experiment_1                  5     -0.442628
# ..                       ...                ...           ...
# 95  Combination_Experiment_1                 96      0.178911
# 96  Combination_Experiment_1                 97      0.179548
# 97  Combination_Experiment_1                 98      0.179548
# 98  Combination_Experiment_1                 99      0.179575
# 99  Combination_Experiment_1                100      0.179575
#
# [100 rows x 3 columns]

# %%
def plot_fitness_for_single_experiment(experiment_name):
    fitnerss_based_df = get_max_fitness_by_generation(df_combined, [Experiments[0]])
    
    plt.figure(figsize=(10, 6))  # Set the size of the plot

    # Create a line plot
    sns.lineplot(data=fitnerss_based_df, x='Generation Number', y='Best Fitness', marker='o',)

    # Adding titles and labels
    plt.title(f'Best Fitness Over Generations for {experiment_name_dict[experiment_name]}')
    plt.xlabel('Generation Number')
    plt.ylabel('Best Fitness')

    # Show the plot
    plt.show()

# %%
plot_fitness_for_single_experiment(Experiments[0])

# %%
def plot_fitness_for_multiple_experiments(experiment_names):
    
    df = df_combined.copy()
    
    # Get the max fitness by generation for the specified experiments
    fitness_based_df = get_max_fitness_by_generation(df, experiment_names)
    
    # Group by 'Experiment Name' and 'Generation Number', then get the max 'Best Fitness'
    fitness_based_df = fitness_based_df.groupby(['Experiment Name', 'Generation Number'])['Best Fitness'].max()

    # Reset the index to turn it back to a DataFrame
    fitness_based_df = fitness_based_df.reset_index()
    
    plt.figure(figsize=(10, 6))  # Set the size of the plot

    # Create a line plot for each experiment
    for experiment_name in experiment_names:
        sns.lineplot(data=fitness_based_df[fitness_based_df['Experiment Name'] == experiment_name], 
                     x='Generation Number', y='Best Fitness', marker='o', label=experiment_name)

    # Adding titles and labels
    plt.title('Best Fitness Over Generations')
    plt.xlabel('Generation Number')
    plt.ylabel('Best Fitness')
    plt.legend(title='Experiment Name')

    # Show the plot
    plt.show()

# %%
plot_fitness_for_multiple_experiments([Experiments[0], Experiments[1], Experiments[2], Experiments[3]])
